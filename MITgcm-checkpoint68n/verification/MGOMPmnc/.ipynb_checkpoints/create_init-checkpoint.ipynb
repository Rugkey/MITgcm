# %%
#!/usr/bin/env python3
"""
微塑料全球海洋模拟脚本
基于MITgcm模型，实现微塑料在全球海洋中的传输模拟

功能：
1. 创建高斯随机分布的微塑料初始场
2. 处理河口微塑料排放数据
3. 使用topo.bin将陆地浓度置零
4. 可视化浓度和河口情况
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import ndimage
import os

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

class MicroplasticSimulation:
    def __init__(self, nx=180, ny=80, nz=40):
        """初始化微塑料模拟类"""
        self.nx = nx
        self.ny = ny 
        self.nz = nz
        
        # 网格设置
        self.dx = 2.0  # 经度分辨率 (度)
        self.dy = 2.0  # 纬度分辨率 (度)
        
        # 坐标网格
        self.lon = np.arange(0, 360, self.dx)  # 经度: 0-358度
        self.lat = np.arange(-80, 80, self.dy)  # 纬度: -80到78度
        
        print(f"网格设置: {nx} x {ny} x {nz}")
        print(f"经度范围: {self.lon[0]}° - {self.lon[-1]}°")
        print(f"纬度范围: {self.lat[0]}° - {self.lat[-1]}°")
    
    def load_river_emissions(self, csv_file='river_emissions.csv'):
        """加载河口微塑料浓度数据"""
        print("加载河口微塑料浓度数据...")
        
        df = pd.read_csv(csv_file)
        rivers = df['rivers'].values
        lats = df['lat'].values  
        lons = df['lon'].values
        # 统一经度到 [0, 360]
        lons = np.mod(lons, 360.0)
        concentrations = df['Mid'].values
        
        print(f"加载了 {len(rivers)} 个河口的浓度数据")
        print(f"浓度范围: {concentrations.min():.2f} - {concentrations.max():.2f}")
        
        return rivers, lats, lons, concentrations
    
    def fill_missing_with_gaussian(self, field_3d, ocean_mask, mean=5.0, std=1000.0, correlation_length=8.0):
        """仅在海洋且当前为0的网格，用掩膜归一化高斯进行填充（表层及各层）。"""
        print("仅填充海洋中缺失(为0)的网格为高斯背景...")

        sigma = correlation_length / self.dx
        eps = 1e-6

        for k in range(self.nz):
            layer = field_3d[k]
            need_fill_mask = (layer <= 0) & ocean_mask

            if not np.any(need_fill_mask):
                continue

            noise = np.random.normal(0.0, 1.0, (self.ny, self.nx)) * need_fill_mask
            num = ndimage.gaussian_filter(noise, sigma=sigma, mode='nearest')
            den = ndimage.gaussian_filter(need_fill_mask.astype(float), sigma=sigma, mode='nearest')
            smooth = num / np.maximum(den, eps)

            ocean_values = smooth[need_fill_mask]
            ocean_mean = ocean_values.mean() if ocean_values.size > 0 else 0.0
            ocean_std = ocean_values.std() if ocean_values.size > 0 else 1.0
            if ocean_std < 1e-12:
                ocean_std = 1.0

            scaled = mean + std * (smooth - ocean_mean) / ocean_std
            scaled = np.maximum(scaled, 0.0)
            layer[need_fill_mask] = scaled[need_fill_mask]

            field_3d[k] = layer

        return field_3d
    
    # 已移除“移动到最近海洋点”的逻辑，改为简单映射到最近网格点
    
    def add_river_emissions(self, field_3d, rivers, lats, lons, concentrations, decay_radius=8.0):
        """在最近海洋格点设置河口浓度，并在周围做高斯扩散。
        - decay_radius: 扩散半径（单位：格）"""
        print("设置河口微塑料浓度(含高斯扩散)...")
        
        # 加载地形数据用于判断海洋/陆地
        topo_file = 'input/ETOPO/topo.bin'
        if os.path.exists(topo_file):
            with open(topo_file, 'rb') as f:
                topo_data = np.fromfile(f, dtype='>f4').reshape((self.ny, self.nx))
            print(f"地形数据加载成功: 形状{topo_data.shape}, 范围{topo_data.min():.1f}到{topo_data.max():.1f}")
        else:
            print("警告: 找不到topo.bin文件，无法判断海洋/陆地")
            topo_data = np.zeros((self.ny, self.nx))  # 假设都是海洋
        
        # 创建河口浓度场(表层)
        river_field_2d = np.zeros((self.ny, self.nx))
        moved_rivers = 0

        # 河口数据本身就是浓度单位；设置到最近“通海”的海洋格点（更大半径、邻居优先）
        for i, (river, lat, lon, concentration) in enumerate(zip(rivers, lats, lons, concentrations)):
            # 直接映射到最近海洋网格（掩膜之后执行，确保写在海上）
            lat_idx = int(np.argmin(np.abs(self.lat - lat)))
            lon_idx = int(np.argmin(np.abs(self.lon - lon)))
            # 在更大范围内寻找“更开放”的海洋格点（避免单格封闭海湾）
            def ocean_neighbors_count(j, i):
                count = 0
                for ddy in (-1, 0, 1):
                    for ddx in (-1, 0, 1):
                        if ddy == 0 and ddx == 0:
                            continue
                        jj = j + ddy
                        ii = i + ddx
                        if 0 <= jj < self.ny and 0 <= ii < self.nx and topo_data[jj, ii] < 0:
                            count += 1
                return count

            best = None  # (neighbors, -distance, depth_abs, j, i)
            max_radius = 20
            for radius in range(0, max_radius + 1):
                for dy in range(-radius, radius + 1):
                    for dx in range(-radius, radius + 1):
                        j = lat_idx + dy
                        i = lon_idx + dx
                        if not (0 <= j < self.ny and 0 <= i < self.nx):
                            continue
                        if topo_data[j, i] < 0:
                            neighbors = ocean_neighbors_count(j, i)
                            dist = np.hypot(dx, dy)
                            depth_abs = -topo_data[j, i]
                            cand = (neighbors, -dist, depth_abs, j, i)
                            if (best is None) or (cand > best):
                                best = cand
                # 早停：一旦半径增长到某层已经找到较好候选且邻居数较多
                if best is not None and best[0] >= 5 and radius >= 3:
                    break

            if best is not None:
                lat_idx, lon_idx = best[3], best[4]

            # 调试打印：标注点最终是否在海洋
            is_ocean = topo_data[lat_idx, lon_idx] < 0
            if i < 15:  # 打印前15个以免刷屏
                print(f"  调试-河口 '{river}': 目标({lat:.2f}N,{lon:.2f}E) -> 网格({lat_idx},{lon_idx}), 深度={topo_data[lat_idx, lon_idx]:.1f}m, 海洋={is_ocean}")
            
            # 在河口周围做高斯扩散（中心保持原浓度，周围递减，仅在海洋格点）
            R = int(max(1, round(decay_radius)))
            sigma = max(1e-6, decay_radius / 2.0)
            for dy in range(-R, R + 1):
                for dx in range(-R, R + 1):
                    j = lat_idx + dy
                    i2 = lon_idx + dx
                    if 0 <= j < self.ny and 0 <= i2 < self.nx and topo_data[j, i2] < 0:
                        r = np.hypot(dx, dy)
                        if r <= decay_radius:
                            weight = np.exp(-0.5 * (r / sigma) ** 2)
                            candidate_value = concentration * weight
                            # 取较大值，避免被更小的扩散值覆盖
                            if candidate_value > river_field_2d[j, i2]:
                                river_field_2d[j, i2] = candidate_value
            
            if i < 10:
                print(f"  {river}: ({lat:.1f}°N, {lon:.1f}°E) -> 网格({lat_idx}, {lon_idx}), 中心浓度: {concentration:.1f}, 扩散半径: {decay_radius}")
        
        # 在河口位置替换背景浓度，而不是叠加
        final_field = field_3d.copy()
        river_mask = river_field_2d > 0
        final_field[0, river_mask] = river_field_2d[river_mask]
        
        print(f"河口浓度统计:")
        print(f"  移动到海洋的河口数: {moved_rivers} / {len(rivers)}")
        print(f"  河口总浓度: {river_field_2d.sum():.2f}")
        print(f"  有河口浓度的网格点: {np.count_nonzero(river_field_2d)}")
        print(f"  最大河口浓度: {river_field_2d.max():.1f}")
        print(f"  应用前场总浓度: {field_3d.sum():.2f}")
        print(f"  应用后场总浓度: {final_field.sum():.2f}")
        
        return final_field, river_field_2d
    
    def apply_ocean_mask(self, field_3d, topo_file='input/ETOPO/topo.bin'):
        """使用topo.bin将陆地浓度置零（严格：topo<0 视为海洋）。"""
        print("应用海洋掩膜...")
        
        try:
            with open(topo_file, 'rb') as f:
                topo_data = np.frombuffer(f.read(), dtype='>f4')
            
            topo_2d = topo_data.reshape(self.ny, self.nx)
            ocean_mask = topo_2d < 0
    
            # 应用掩膜前的统计
            print(f"应用掩膜前:")
            print(f"  总浓度: {field_3d.sum():.2f}")
            print(f"  非零网格点: {np.count_nonzero(field_3d)}")
            print(f"  最大浓度: {field_3d.max():.6f}")
            
            for k in range(self.nz):
                field_3d[k, :, :] = field_3d[k, :, :] * ocean_mask
            
            print(f"海洋掩膜应用完成")
            print(f"  海洋网格点: {np.count_nonzero(ocean_mask)}")
            print(f"  陆地网格点: {np.count_nonzero(~ocean_mask)}")
            print(f"  海洋覆盖率: {np.count_nonzero(ocean_mask) / (self.ny * self.nx) * 100:.1f}%")
            print(f"应用掩膜后:")
            print(f"  总浓度: {field_3d.sum():.2f}")
            print(f"  非零网格点: {np.count_nonzero(field_3d)}")
            print(f"  最大浓度: {field_3d.max():.6f}")
            
        except FileNotFoundError:
            print(f"警告: 未找到地形文件 {topo_file}")
            print("跳过海洋掩膜应用")
        
        return field_3d
    
    def write_binary_file(self, field_3d, filename):
        """将3D场写入二进制文件"""
        print(f"写入二进制文件: {filename}")
        
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        
        with open(filename, 'wb') as f:
            f.write(field_3d.astype('>f4').tobytes())
        
        print(f"文件大小: {os.path.getsize(filename) / 1024 / 1024:.2f} MB")
    
    def create_visualization(self, field_3d, rivers, lats, lons, concentrations, output_dir='results'):
        """创建简化可视化：1) 浓度分布 2) 河口位置"""
        print("创建简化可视化...")
        
        os.makedirs(output_dir, exist_ok=True)
        
        # 创建坐标网格
        lon_grid, lat_grid = np.meshgrid(self.lon, self.lat)
        surface_field = field_3d[0, :, :]
        
        # 计算移动后的河口坐标用于可视化
        print("计算移动后的河口坐标用于可视化...")
        topo_file = 'input/ETOPO/topo.bin'
        if os.path.exists(topo_file):
            with open(topo_file, 'rb') as f:
                topo_data = np.fromfile(f, dtype='>f4').reshape((self.ny, self.nx))
        else:
            topo_data = np.zeros((self.ny, self.nx))
        
        # 存储移动后的坐标
        moved_lats = []
        moved_lons = []
        
        for river, lat, lon in zip(rivers, lats, lons):
            # 最近网格索引
            lat_idx = int(np.argmin(np.abs(self.lat - lat)))
            lon_idx = int(np.argmin(np.abs(self.lon - lon)))
            # 使用与赋值相同的“通海优先”搜索
            def ocean_neighbors_count(j, i):
                count = 0
                for ddy in (-1, 0, 1):
                    for ddx in (-1, 0, 1):
                        if ddy == 0 and ddx == 0:
                            continue
                        jj = j + ddy
                        ii = i + ddx
                        if 0 <= jj < self.ny and 0 <= ii < self.nx and topo_data[jj, ii] < 0:
                            count += 1
                return count

            best = None
            max_radius = 20
            for radius in range(0, max_radius + 1):
                for dy in range(-radius, radius + 1):
                    for dx in range(-radius, radius + 1):
                        j = lat_idx + dy
                        i = lon_idx + dx
                        if not (0 <= j < self.ny and 0 <= i < self.nx):
                            continue
                        if topo_data[j, i] < 0:
                            neighbors = ocean_neighbors_count(j, i)
                            dist = np.hypot(dx, dy)
                            depth_abs = -topo_data[j, i]
                            cand = (neighbors, -dist, depth_abs, j, i)
                            if (best is None) or (cand > best):
                                best = cand
                if best is not None and best[0] >= 5 and radius >= 3:
                    break

            if best is not None:
                lat_idx, lon_idx = best[3], best[4]
            # 调试打印：用于确认标注点是否在海洋
            is_ocean = topo_data[lat_idx, lon_idx] < 0
            print(f"  可视化-河口 '{river}': 网格({lat_idx},{lon_idx}), 深度={topo_data[lat_idx, lon_idx]:.1f}m, 海洋={is_ocean}")
            moved_lats.append(self.lat[lat_idx])
            moved_lons.append(self.lon[lon_idx])
        
        moved_lats = np.array(moved_lats)
        moved_lons = np.array(moved_lons)
        
        # 图1：浓度分布（陆地单独着色）
        fig1, ax1 = plt.subplots(1, 1, figsize=(20, 10))
        ocean_mask = topo_data < 0
        masked_surface = np.ma.masked_where(~ocean_mask, surface_field)
        cmap1 = plt.cm.get_cmap('viridis').copy()
        cmap1.set_bad(color='lightgray')  # 陆地为浅灰
        im1 = ax1.pcolormesh(lon_grid, lat_grid, masked_surface, cmap=cmap1, shading='auto')
        ax1.set_xlabel('经度', fontsize=14)
        ax1.set_ylabel('纬度', fontsize=14)
        ax1.set_title('全球海洋微塑料浓度分布 (kg/m³)', fontsize=16, fontweight='bold')
        ax1.set_xlim(0, 360)
        ax1.set_ylim(-80, 80)
        ax1.grid(True, alpha=0.3)
        cbar1 = plt.colorbar(im1, ax=ax1, orientation='horizontal', shrink=0.8, pad=0.1)
        cbar1.set_label('微塑料浓度 (kg/m³)', fontsize=12)
        plt.tight_layout()
        plt.savefig(f'{output_dir}/global_concentration.png', dpi=300, bbox_inches='tight')
        plt.show()

        # 图2：河口位置（仅标记河口，陆地单独着色）
        fig2, ax2 = plt.subplots(1, 1, figsize=(20, 10))
        # 使用二值掩膜上色：0(陆地)=浅灰，1(海洋)=白色
        from matplotlib.colors import ListedColormap
        mask_binary = (topo_data < 0).astype(float)
        land_ocean_cmap = ListedColormap(['lightgray', 'white'])
        ax2.pcolormesh(lon_grid, lat_grid, mask_binary, cmap=land_ocean_cmap, shading='auto')
        ax2.scatter(moved_lons, moved_lats, c='red', s=np.clip(concentrations/1000, 10, 200), alpha=0.7, edgecolors='white', linewidth=1)
        ax2.set_xlabel('经度', fontsize=14)
        ax2.set_ylabel('纬度', fontsize=14)
        ax2.set_title('河口位置与相对大小（按浓度缩放）', fontsize=16, fontweight='bold')
        ax2.set_xlim(0, 360)
        ax2.set_ylim(-80, 80)
        ax2.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(f'{output_dir}/river_locations.png', dpi=300, bbox_inches='tight')
        plt.show()
    
    def run_simulation(self):
        """运行完整的微塑料模拟"""
        print("=" * 60)
        print("微塑料全球海洋模拟")
        print("=" * 60)
        
        # 1. 加载地形并生成海洋掩膜
        print("\n1. 加载地形并生成海洋掩膜...")
        with open('input/ETOPO/topo.bin', 'rb') as f:
            topo_data = np.fromfile(f, dtype='>f4').reshape((self.ny, self.nx))
        ocean_mask = topo_data < 0

        # 2. 加载河口浓度数据
        print("\n2. 加载河口浓度数据...")
        rivers, lats, lons, concentrations = self.load_river_emissions()
        
        # 3. 初始化场(全0)，设置河口到最近海洋格点
        print("\n3. 初始化场并写入河口...")
        initial_field = np.zeros((self.nz, self.ny, self.nx))
        field_with_rivers, river_field_2d = self.add_river_emissions(initial_field, rivers, lats, lons, concentrations)

        # 4. 仅在海洋且为0的地方填充高斯背景
        print("\n4. 高斯填充海洋缺失区域...")
        final_field = self.fill_missing_with_gaussian(field_with_rivers, ocean_mask)

        # 5. 创建可视化（两张图）
        print("\n5. 创建可视化...")
        self.create_visualization(final_field, rivers, lats, lons, concentrations)
        
        # 6. 写入二进制文件
        print("\n6. 写入MITgcm输入文件...")
        self.write_binary_file(final_field, 'input/microplastic_initial.bin')
        # 生成 RBCS 目标与掩膜（表层河口处松弛，不影响深层）
        rbcs_target = np.zeros_like(final_field)
        rbcs_target[0, :, :] = river_field_2d
        rbcs_mask = np.zeros_like(final_field)
        rbcs_mask[0, :, :] = (river_field_2d > 0.0).astype(np.float32)
        self.write_binary_file(rbcs_target, 'input/microplastic_rbcs_target.bin')
        self.write_binary_file(rbcs_mask, 'input/microplastic_rbcs_mask.bin')
        
        print("\n" + "=" * 60)
        print("微塑料模拟完成!")
        print("=" * 60)
        
        return final_field

def main():
    """主函数"""
    sim = MicroplasticSimulation(nx=180, ny=80, nz=40)
    field_3d = sim.run_simulation()
    
    print(f"\n模拟完成! 生成的3D场形状: {field_3d.shape}")
    print(f"文件已保存到: input/microplastic_initial.bin")

if __name__ == "__main__":
    main()
# Out:
# 网格设置: 180 x 80 x 40
# 经度范围: 0.0° - 358.0°
# 纬度范围: -80.0° - 78.0°
# ============================================================
# 微塑料全球海洋模拟
# ============================================================
#
# 1. 加载地形并生成海洋掩膜...
#
# 2. 加载河口浓度数据...
# 加载河口微塑料浓度数据...
# 加载了 1048 个河口的浓度数据
# 浓度范围: 0.58 - 14994.68
#
# 3. 初始化场并写入河口...
# 设置河口微塑料浓度(含高斯扩散)...
# 地形数据加载成功: 形状(80, 180), 范围-6446.2到0.0
#   调试-河口 'Congo': 目标(-6.00N,12.30E) -> 网格(36,4), 深度=-4020.8m, 海洋=True
#   Congo: (-6.0°N, 12.3°E) -> 网格(36, 4), 中心浓度: 2621.5, 扩散半径: 8.0
#   调试-河口 'Rhine': 目标(51.90N,4.00E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Rhine: (51.9°N, 4.0°E) -> 网格(68, 1), 中心浓度: 1839.7, 扩散半径: 8.0
#   调试-河口 'Niger': 目标(6.40N,3.40E) -> 网格(41,1), 深度=-4097.9m, 海洋=True
#   Niger: (6.4°N, 3.4°E) -> 网格(41, 1), 中心浓度: 1219.9, 扩散半径: 8.0
#   调试-河口 'Elbe': 目标(53.50N,8.70E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Elbe: (53.5°N, 8.7°E) -> 网格(68, 1), 中心浓度: 469.8, 扩散半径: 8.0
#   调试-河口 'Rhone': 目标(43.70N,4.80E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   Rhone: (43.7°N, 4.8°E) -> 网格(67, 2), 中心浓度: 391.2, 扩散半径: 8.0
#   调试-河口 'Po': 目标(44.80N,12.40E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Cross': 目标(4.60N,8.30E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Cross: (4.6°N, 8.3°E) -> 网格(40, 3), 中心浓度: 286.7, 扩散半径: 8.0
#   调试-河口 'Weser': 目标(53.20N,8.60E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Weser: (53.2°N, 8.6°E) -> 网格(68, 1), 中心浓度: 269.0, 扩散半径: 8.0
#   调试-河口 'Maas': 目标(51.90N,4.20E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Maas: (51.9°N, 4.2°E) -> 网格(68, 1), 中心浓度: 223.1, 扩散半径: 8.0
#   调试-河口 'Ogun': 目标(6.90N,3.40E) -> 网格(41,1), 深度=-4097.9m, 海洋=True
#   Ogun: (6.9°N, 3.4°E) -> 网格(41, 1), 中心浓度: 199.5, 扩散半径: 8.0
#   调试-河口 'Osse': 目标(44.30N,0.20E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Osse: (44.3°N, 0.2°E) -> 网格(67, 1), 中心浓度: 135.7, 扩散半径: 8.0
#   调试-河口 'Seine': 目标(49.00N,2.30E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Seine: (49.0°N, 2.3°E) -> 网格(67, 1), 中心浓度: 125.8, 扩散半径: 8.0
#   调试-河口 'Thames': 目标(51.50N,0.10E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Thames: (51.5°N, 0.1°E) -> 网格(68, 1), 中心浓度: 121.7, 扩散半径: 8.0
#   调试-河口 'Ems': 目标(53.30N,7.10E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Ems: (53.3°N, 7.1°E) -> 网格(68, 1), 中心浓度: 93.7, 扩散半径: 8.0
#   调试-河口 'Sanaga': 目标(3.60N,9.70E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Sanaga: (3.6°N, 9.7°E) -> 网格(40, 3), 中心浓度: 80.0, 扩散半径: 8.0
#   调试-河口 'Oder': 目标(53.50N,14.50E) -> 网格(67,3), 深度=-30.9m, 海洋=True
#   调试-河口 'Brenta': 目标(45.40N,12.00E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Wouri': 目标(4.00N,9.70E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Wouri: (4.0°N, 9.7°E) -> 网格(40, 3), 中心浓度: 54.6, 扩散半径: 8.0
#   调试-河口 'Cuanza': 目标(-9.10N,13.20E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Scheldt': 目标(51.20N,4.30E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Scheldt: (51.2°N, 4.3°E) -> 网格(68, 1), 中心浓度: 47.1, 扩散半径: 8.0
#   调试-河口 'Tevere': 目标(41.90N,12.50E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Kouilou': 目标(-4.50N,11.40E) -> 网格(36,4), 深度=-4020.8m, 海洋=True
#   Kouilou: (-4.5°N, 11.4°E) -> 网格(36, 4), 中心浓度: 38.0, 扩散半径: 8.0
#   调试-河口 'Oueme': 目标(6.40N,2.60E) -> 网格(41,1), 深度=-4097.9m, 海洋=True
#   Oueme: (6.4°N, 2.6°E) -> 网格(41, 1), 中心浓度: 35.7, 扩散半径: 8.0
#   调试-河口 'Ogooue': 目标(-0.70N,10.20E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Ogooue: (-0.7°N, 10.2°E) -> 网格(40, 3), 中心浓度: 30.5, 扩散半径: 8.0
#   调试-河口 'Ebro': 目标(40.70N,0.20E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Ebro: (40.7°N, 0.2°E) -> 网格(67, 1), 中心浓度: 28.7, 扩散半径: 8.0
#   调试-河口 'Adige': 目标(45.60N,12.40E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Mono': 目标(6.40N,1.70E) -> 网格(41,1), 深度=-4097.9m, 海洋=True
#   Mono: (6.4°N, 1.7°E) -> 网格(41, 1), 中心浓度: 23.1, 扩散半径: 8.0
#   调试-河口 'El Harrach': 目标(36.70N,3.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Chiloango': 目标(-5.10N,12.40E) -> 网格(36,4), 深度=-4020.8m, 海洋=True
#   Chiloango: (-5.1°N, 12.4°E) -> 网格(36, 4), 中心浓度: 17.3, 扩散半径: 8.0
#   调试-河口 'Wadi Baraka': 目标(20.70N,10.50E) -> 网格(42,1), 深度=-3188.7m, 海洋=True
#   调试-河口 'Seli': 目标(62.30N,9.70E) -> 网格(68,2), 深度=-71.8m, 海洋=True
#   Seli: (62.3°N, 9.7°E) -> 网格(68, 2), 中心浓度: 15.9, 扩散半径: 8.0
#   调试-河口 'Cuvo': 目标(-12.10N,14.40E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Kebir': 目标(36.90N,3.30E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Mungo': 目标(4.20N,9.70E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Mungo: (4.2°N, 9.7°E) -> 网格(40, 3), 中心浓度: 11.8, 扩散半径: 8.0
#   调试-河口 'Volturno': 目标(41.00N,13.90E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Llobregat': 目标(41.30N,2.20E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Llobregat: (41.3°N, 2.2°E) -> 网格(67, 1), 中心浓度: 11.2, 扩散半径: 8.0
#   调试-河口 'Arno': 目标(43.80N,10.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Bengo': 目标(-8.50N,13.40E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Diep': 目标(51.00N,3.40E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Diep: (51.0°N, 3.4°E) -> 网格(68, 1), 中心浓度: 9.7, 扩散半径: 8.0
#   调试-河口 'Glomma': 目标(59.20N,11.20E) -> 网格(68,3), 深度=-109.5m, 海洋=True
#   Glomma: (59.2°N, 11.2°E) -> 网格(68, 3), 中心浓度: 8.4, 扩散半径: 8.0
#   调试-河口 'Besos': 目标(41.40N,2.20E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Besos: (41.4°N, 2.2°E) -> 网格(67, 1), 中心浓度: 8.3, 扩散半径: 8.0
#   调试-河口 'Nyong': 目标(3.50N,9.80E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Nyong: (3.5°N, 9.8°E) -> 网格(40, 3), 中心浓度: 7.8, 扩散半径: 8.0
#   调试-河口 'Cunene': 目标(-17.30N,12.40E) -> 网格(31,4), 深度=-4504.7m, 海洋=True
#   Cunene: (-17.3°N, 12.4°E) -> 网格(31, 4), 中心浓度: 7.6, 扩散半径: 8.0
#   调试-河口 'Lobe': 目标(2.90N,9.90E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Lobe: (2.9°N, 9.9°E) -> 网格(40, 3), 中心浓度: 7.6, 扩散半径: 8.0
#   调试-河口 'Piave': 目标(45.50N,12.60E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Wye': 目标(51.20N,0.90E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Wye: (51.2°N, 0.9°E) -> 网格(68, 1), 中心浓度: 7.4, 扩散半径: 8.0
#   调试-河口 'Orange': 目标(-28.60N,16.50E) -> 网格(25,6), 深度=-3114.9m, 海洋=True
#   调试-河口 'Liri': 目标(41.40N,13.80E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Sebaou': 目标(36.80N,4.30E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Soumman': 目标(36.70N,3.80E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Coporolo': 目标(-14.60N,12.30E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   Coporolo: (-14.6°N, 12.3°E) -> 网格(34, 5), 中心浓度: 4.9, 扩散半径: 8.0
#   调试-河口 'Groot Berg': 目标(-19.70N,14.20E) -> 网格(28,5), 深度=-3496.4m, 海洋=True
#   调试-河口 'Breede': 目标(-34.40N,20.30E) -> 网格(21,10), 深度=-2364.0m, 海洋=True
#   调试-河口 'Longa': 目标(-9.00N,13.30E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Goumo': 目标(10.10N,9.50E) -> 网格(42,2), 深度=-575.5m, 海洋=True
#   Goumo: (10.1°N, 9.5°E) -> 网格(42, 2), 中心浓度: 4.4, 扩散半径: 8.0
#   调试-河口 'Oria': 目标(40.60N,13.00E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Ter': 目标(42.00N,2.60E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Ter: (42.0°N, 2.6°E) -> 网格(67, 1), 中心浓度: 4.2, 扩散半径: 8.0
#   调试-河口 'Reno': 目标(44.50N,11.00E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Swakop': 目标(-22.70N,14.50E) -> 网格(28,5), 深度=-3496.4m, 海洋=True
#   调试-河口 'M'Bridge': 目标(36.30N,2.30E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   调试-河口 'Magra': 目标(44.00N,9.90E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Somme': 目标(50.20N,2.30E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Somme: (50.2°N, 2.3°E) -> 网格(68, 1), 中心浓度: 3.5, 扩散半径: 8.0
#   调试-河口 'Mazafran': 目标(36.80N,2.60E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   调试-河口 'Chéliff': 目标(36.10N,1.30E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   调试-河口 'Majardah': 目标(37.10N,10.10E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Mellah': 目标(36.50N,6.90E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Loge': 目标(-8.80N,13.20E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Var': 目标(43.70N,7.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   Var: (43.7°N, 7.2°E) -> 网格(67, 2), 中心浓度: 3.0, 扩散半径: 8.0
#   调试-河口 'Ntem': 目标(2.30N,9.80E) -> 网格(40,3), 深度=-2732.2m, 海洋=True
#   Ntem: (2.3°N, 9.8°E) -> 网格(40, 3), 中心浓度: 2.8, 扩散半径: 8.0
#   调试-河口 'Nyanga': 目标(-2.60N,10.00E) -> 网格(39,3), 深度=-2952.5m, 海洋=True
#   Nyanga: (-2.6°N, 10.0°E) -> 网格(39, 3), 中心浓度: 2.7, 扩散半径: 8.0
#   调试-河口 'Herault': 目标(43.40N,3.70E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   Herault: (43.4°N, 3.7°E) -> 网格(67, 2), 中心浓度: 2.5, 扩散半径: 8.0
#   调试-河口 'Tagliamento': 目标(45.70N,13.10E) -> 网格(67,3), 深度=-30.9m, 海洋=True
#   调试-河口 'Seybousse': 目标(35.90N,7.30E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Drammenselva': 目标(59.70N,10.20E) -> 网格(68,2), 深度=-71.8m, 海洋=True
#   Drammenselva: (59.7°N, 10.2°E) -> 网格(68, 2), 中心浓度: 2.3, 扩散半径: 8.0
#   调试-河口 'Argens': 目标(43.40N,6.10E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   Argens: (43.4°N, 6.1°E) -> 网格(67, 2), 中心浓度: 2.3, 扩散半径: 8.0
#   调试-河口 'Ketanda': 目标(-4.30N,19.50E) -> 网格(34,6), 深度=-1069.0m, 海洋=True
#   调试-河口 'Savio': 目标(44.10N,12.60E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Aude': 目标(43.10N,2.90E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Aude: (43.1°N, 2.9°E) -> 网格(67, 1), 中心浓度: 2.0, 扩散半径: 8.0
#   调试-河口 'Esino': 目标(43.60N,1.20E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Esino: (43.6°N, 1.2°E) -> 网格(67, 1), 中心浓度: 2.0, 扩散半径: 8.0
#   调试-河口 'Wadi Tuban': 目标(-12.30N,13.20E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Sele': 目标(59.10N,15.30E) -> 网格(68,3), 深度=-109.5m, 海洋=True
#   调试-河口 'Skiensvassdraget': 目标(40.20N,9.60E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'G?ta alv': 目标(58.30N,12.00E) -> 网格(68,3), 深度=-109.5m, 海洋=True
#   G?ta alv: (58.3°N, 12.0°E) -> 网格(68, 3), 中心浓度: 1.9, 扩散半径: 8.0
#   调试-河口 'Catumbela': 目标(-12.60N,13.50E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Pescara': 目标(42.50N,14.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Smith': 目标(-33.60N,18.10E) -> 网格(21,9), 深度=-3720.9m, 海洋=True
#   调试-河口 'Parsenta': 目标(54.30N,16.50E) -> 网格(67,3), 深度=-30.9m, 海洋=True
#   调试-河口 'George': 目标(-33.60N,22.60E) -> 网格(21,11), 深度=-3897.3m, 海洋=True
#   调试-河口 'Orb': 目标(44.10N,1.60E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Orb: (44.1°N, 1.6°E) -> 网格(67, 1), 中心浓度: 1.5, 扩散半径: 8.0
#   调试-河口 'Isser': 目标(36.70N,2.80E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   调试-河口 'Balombo': 目标(-11.40N,13.80E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Krka': 目标(45.80N,14.80E) -> 网格(67,3), 深度=-30.9m, 海洋=True
#   调试-河口 'Curoca': 目标(-18.00N,12.30E) -> 网格(31,4), 深度=-4504.7m, 海洋=True
#   Curoca: (-18.0°N, 12.3°E) -> 网格(31, 4), 中心浓度: 1.1, 扩散半径: 8.0
#   调试-河口 'Tirso': 目标(39.90N,13.60E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Sella': 目标(43.30N,0.60E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Sella: (43.3°N, 0.6°E) -> 网格(67, 1), 中心浓度: 1.0, 扩散半径: 8.0
#   调试-河口 'Musone': 目标(43.30N,13.40E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Tet': 目标(42.70N,2.90E) -> 网格(67,1), 深度=-36.2m, 海洋=True
#   Tet: (42.7°N, 2.9°E) -> 网格(67, 1), 中心浓度: 1.0, 扩散半径: 8.0
#   调试-河口 'Biferno': 目标(41.60N,14.90E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Cambongo': 目标(-8.80N,13.40E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Ombrone': 目标(42.70N,11.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Boko': 目标(-6.60N,12.40E) -> 网格(36,4), 深度=-4020.8m, 海洋=True
#   Boko: (-6.6°N, 12.4°E) -> 网格(36, 4), 中心浓度: 0.8, 扩散半径: 8.0
#   调试-河口 'Rega': 目标(54.20N,14.80E) -> 网格(67,3), 深度=-30.9m, 海洋=True
#   调试-河口 'Chienti': 目标(43.20N,13.10E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Cubal': 目标(-13.80N,13.10E) -> 网格(34,5), 深度=-3456.1m, 海洋=True
#   调试-河口 'Numedalslagen': 目标(59.60N,8.30E) -> 网格(68,1), 深度=-73.8m, 海洋=True
#   Numedalslagen: (59.6°N, 8.3°E) -> 网格(68, 1), 中心浓度: 0.8, 扩散半径: 8.0
#   调试-河口 'Kaituna': 目标(-37.70N,20.10E) -> 网格(21,10), 深度=-2364.0m, 海洋=True
#   调试-河口 'Lamone': 目标(44.20N,12.20E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Fortore': 目标(41.40N,15.30E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Foglia': 目标(43.80N,12.80E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Sangro': 目标(41.90N,14.40E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Marecchia': 目标(44.00N,12.70E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Tenna': 目标(42.90N,13.80E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Ofanto': 目标(41.20N,15.90E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Tronto': 目标(42.80N,13.70E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Misa': 目标(43.50N,13.10E) -> 网格(67,2), 深度=-39.7m, 海洋=True
#   调试-河口 'Ligonha': 目标(-14.80N,9.70E) -> 网格(33,4), 深度=-4452.8m, 海洋=True
#   Ligonha: (-14.8°N, 9.7°E) -> 网格(33, 4), 中心浓度: 0.6, 扩散半径: 8.0
#   调试-河口 'Mananan Tanana': 目标(63.00N,12.60E) -> 网格(68,3), 深度=-109.5m, 海洋=True
#   Mananan Tanana: (63.0°N, 12.6°E) -> 网格(68, 3), 中心浓度: 0.6, 扩散半径: 8.0
# 河口浓度统计:
#   移动到海洋的河口数: 0 / 1048
#   河口总浓度: 2993712.63
#   有河口浓度的网格点: 5087
#   最大河口浓度: 14994.7
#   应用前场总浓度: 0.00
#   应用后场总浓度: 2993712.63
#
# 4. 高斯填充海洋缺失区域...
# 仅填充海洋中缺失(为0)的网格为高斯背景...
#
# 5. 创建可视化...
# 创建简化可视化...
# 计算移动后的河口坐标用于可视化...
#   可视化-河口 'Changjiang': 网格(55,62), 深度=-55.2m, 海洋=True
#   可视化-河口 'Brahmaputra': 网格(50,44), 深度=-241.7m, 海洋=True
#   可视化-河口 'Ganges': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Vaippar': 网格(43,40), 深度=-1.9m, 海洋=True
#   可视化-河口 'Amazon': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'Bekasi': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Vaigai': 网格(45,41), 深度=-3551.1m, 海洋=True
#   可视化-河口 'Mekong': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Irrawaddy': 网格(47,46), 深度=-1711.7m, 海洋=True
#   可视化-河口 'Congo': 网格(36,4), 深度=-4020.8m, 海洋=True
#   可视化-河口 'Magdalena': 网格(47,143), 深度=-3387.2m, 海洋=True
#   可视化-河口 'Zhujiang': 网格(49,57), 深度=-2442.9m, 海洋=True
#   可视化-河口 'Paraná': 网格(20,152), 深度=-965.6m, 海洋=True
#   可视化-河口 'Meghna': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Shatt el Arab': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Orinoco': 网格(46,149), 深度=-1880.7m, 海洋=True
#   可视化-河口 'Rhine': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Ilog': 网格(45,61), 深度=-105.0m, 海洋=True
#   可视化-河口 'Amur': 网格(67,73), 深度=-841.4m, 海洋=True
#   可视化-河口 'Volga': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Danube': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Mississippi': 网格(53,135), 深度=-2377.9m, 海洋=True
#   可视化-河口 'Niger': 网格(41,1), 深度=-4097.9m, 海洋=True
#   可视化-河口 'Citarum': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Porong': 网格(34,56), 深度=-4097.0m, 海洋=True
#   可视化-河口 'Bengawan Solo': 网格(34,55), 深度=-4795.3m, 海洋=True
#   可视化-河口 'Karun': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Song Hong': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Musi': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Pampanga': 网格(46,60), 深度=-348.8m, 海洋=True
#   可视化-河口 'Tanshui': 网格(53,62), 深度=-455.5m, 海洋=True
#   可视化-河口 'Sai Gon': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Nahualate': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Esmeraldas': 网格(40,138), 深度=-3162.9m, 海洋=True
#   可视化-河口 'Salween': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Progo': 网格(34,55), 深度=-4795.3m, 海洋=True
#   可视化-河口 'Guayas': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Grande de Tarcoles ': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Angat': 网格(46,60), 深度=-348.8m, 海洋=True
#   可视化-河口 'Sittang': 网格(47,46), 深度=-1711.7m, 海洋=True
#   可视化-河口 'Ob'': 网格(72,19), 深度=-0.6m, 海洋=True
#   可视化-河口 'Chao Phraya': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Elbe': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Paraiba do Sul': 网格(29,161), 深度=-3221.4m, 海洋=True
#   可视化-河口 'Neva': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Cagayan': 网格(49,62), 深度=-5416.6m, 海洋=True
#   可视化-河口 'Qiantangjiang': 网格(55,62), 深度=-55.2m, 海洋=True
#   可视化-河口 'Rhone': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Minjiang': 网格(53,62), 深度=-455.5m, 海洋=True
#   可视化-河口 'Haihe': 网格(56,62), 深度=-72.9m, 海洋=True
#   可视化-河口 'Han': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Cimanuk': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Copper': 网格(68,107), 深度=-3757.8m, 海洋=True
#   可视化-河口 'Citanduy': 网格(34,54), 深度=-5235.1m, 海洋=True
#   可视化-河口 'Po': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Godavari': 网格(47,42), 深度=-3032.0m, 海洋=True
#   可视化-河口 'Tocantins': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'St. Lawrence': 网格(61,148), 深度=-888.3m, 海洋=True
#   可视化-河口 'Yodo': 网格(55,68), 深度=-4168.7m, 海洋=True
#   可视化-河口 'Cross': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Mindanao': 网格(45,62), 深度=-281.5m, 海洋=True
#   可视化-河口 'Weser': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Doce': 网格(30,161), 深度=-3032.6m, 海洋=True
#   可视化-河口 'Columbia': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Delaware': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Usumacinta': 网格(51,133), 深度=-3530.2m, 海洋=True
#   可视化-河口 'Hanjiang': 网格(52,61), 深度=-1042.2m, 海洋=True
#   可视化-河口 'Xiaoqinghe': 网格(56,62), 深度=-72.9m, 海洋=True
#   可视化-河口 'Mobile': 网格(53,136), 深度=-2996.2m, 海洋=True
#   可视化-河口 'Maas': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Oujiang': 网格(54,62), 深度=-88.4m, 海洋=True
#   可视化-河口 'Sa? Francisco': 网格(32,161), 深度=-3988.1m, 海洋=True
#   可视化-河口 'Thai Binh': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Yuna': 网格(50,146), 深度=-5419.3m, 海洋=True
#   可视化-河口 'Ogun': 网格(41,1), 深度=-4097.9m, 海洋=True
#   可视化-河口 'Jacuí': 网格(23,155), 深度=-2471.0m, 海洋=True
#   可视化-河口 'Tapi': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Patia': 网格(42,139), 深度=-2558.5m, 海洋=True
#   可视化-河口 'Uruguay': 网格(20,152), 深度=-965.6m, 海洋=True
#   可视化-河口 'Agusan': 网格(45,63), 深度=-5992.1m, 海洋=True
#   可视化-河口 'Hudson': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Bangpakhlong': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Hari': 网格(52,31), 深度=-1012.6m, 海洋=True
#   可视化-河口 'Susquehanna': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Taedong': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Duwamish': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Nile': 网格(46,25), 深度=-1932.2m, 海洋=True
#   可视化-河口 'Tjipunagara': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Purari': 网格(38,74), 深度=-1898.5m, 海洋=True
#   可视化-河口 'Tuy': 网格(46,147), 深度=-3789.1m, 海洋=True
#   可视化-河口 'Lempa': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Nakdong': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Colorado': 网格(53,121), 深度=-3738.6m, 海洋=True
#   可视化-河口 'Kapuas': 网格(42,54), 深度=-98.7m, 海洋=True
#   可视化-河口 'Mahanadi': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Zambezi': 网格(29,19), 深度=-2782.9m, 海洋=True
#   可视化-河口 'Vistula': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Damodar': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Apalachicola': 网格(53,136), 深度=-2996.2m, 海洋=True
#   可视化-河口 'San Juan': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Yaque del Norte': 网格(50,146), 深度=-5419.3m, 海洋=True
#   可视化-河口 'Agno': 网格(48,58), 深度=-3837.0m, 海洋=True
#   可视化-河口 'Osse': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Inderagiri': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Brahmani': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Ca': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Seine': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Mé': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Luni': 网格(49,33), 深度=-3184.9m, 海洋=True
#   可视化-河口 'Papaloapán': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Thames': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Reventazon': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Khlong Phum Duang': 网格(44,47), 深度=-2335.6m, 海洋=True
#   可视化-河口 'Luanhe': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Santee': 网格(56,142), 深度=-3769.6m, 海洋=True
#   可视化-河口 'Ulua': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Indus': 网格(50,32), 深度=-3026.2m, 海洋=True
#   可视化-河口 'Mira': 网格(60,174), 深度=-4000.6m, 海洋=True
#   可视化-河口 'Kolyma': 网格(69,86), 深度=-3463.6m, 海洋=True
#   可视化-河口 'Kaoping': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Kelani Ganga': 网格(43,40), 深度=-1.9m, 海洋=True
#   可视化-河口 'Capim': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'Motagua': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Coco': 网格(47,139), 深度=-695.0m, 海洋=True
#   可视化-河口 'Ishikari': 网格(62,73), 深度=-1468.1m, 海洋=True
#   可视化-河口 'Perak': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Maipo': 网格(23,142), 深度=-4190.6m, 海洋=True
#   可视化-河口 'Grande de Matagalpa': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Cauweri': 网格(45,41), 深度=-3551.1m, 海洋=True
#   可视化-河口 'Weihe': 网格(51,60), 深度=-503.4m, 海洋=True
#   可视化-河口 'Connecticut': 网格(59,145), 深度=-3093.4m, 海洋=True
#   可视化-河口 'Jianjiang': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Verde': 网格(54,122), 深度=-258.4m, 海洋=True
#   可视化-河口 'Ma': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Mersey': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Merrimack': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Don': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Trent': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Huanghe': 网格(56,62), 深度=-72.9m, 海洋=True
#   可视化-河口 'Mahakam': 网格(40,60), 深度=-997.5m, 海洋=True
#   可视化-河口 'Kiso': 网格(55,68), 深度=-4168.7m, 海洋=True
#   可视化-河口 'Tone': 网格(57,71), 深度=-5922.8m, 海洋=True
#   可视化-河口 'Ems': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Bicol': 网格(47,62), 深度=-4316.1m, 海洋=True
#   可视化-河口 'Ribeira do Iguape': 网格(26,157), 深度=-2326.4m, 海洋=True
#   可视化-河口 'Langat': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Yalujiang': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Neveri': 网格(46,148), 深度=-2183.2m, 海洋=True
#   可视化-河口 'Jiulongjiang': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Jinjiang': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Kelantan': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Sacramento': 网格(57,117), 深度=-4440.3m, 海洋=True
#   可视化-河口 'Bia': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Tanjiang': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Barito': 网格(36,58), 深度=-564.2m, 海洋=True
#   可视化-河口 'Trinity': 网格(53,133), 深度=-1360.2m, 海洋=True
#   可视化-河口 'Loire': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Pahang': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Altamaha': 网格(55,141), 深度=-1994.1m, 海洋=True
#   可视化-河口 'Tsengwen': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Sanaga': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Colville': 网格(69,105), 深度=-289.3m, 海洋=True
#   可视化-河口 'Sepik': 网格(39,72), 深度=-2335.4m, 海洋=True
#   可视化-河口 'Khatanga': 网格(61,67), 深度=-1679.8m, 海洋=True
#   可视化-河口 'Grijalva': 网格(51,133), 深度=-3530.2m, 海洋=True
#   可视化-河口 'Oder': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Santiago': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Kampar': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Wu': 网格(50,58), 深度=-676.4m, 海洋=True
#   可视化-河口 'Tachia': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Atrato': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Davai': 网格(45,63), 深度=-5992.1m, 海洋=True
#   可视化-河口 'Mae Klong': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Cavally': 网格(41,176), 深度=-4439.0m, 海洋=True
#   可视化-河口 'Bharathpuzha': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Rewa': 网格(31,89), 深度=-707.3m, 海洋=True
#   可视化-河口 'St. Paul': 网格(41,175), 深度=-4483.1m, 海洋=True
#   可视化-河口 'Shinamo': 网格(60,68), 深度=-3199.6m, 海洋=True
#   可视化-河口 'Agneby': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Balsas': 网格(47,128), 深度=-3300.5m, 海洋=True
#   可视化-河口 'Cudijung': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Itajai-ácu': 网格(26,157), 深度=-2326.4m, 海洋=True
#   可视化-河口 'Drini': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Kuban': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Bio Bio': 网格(22,142), 深度=-4208.8m, 海洋=True
#   可视化-河口 'Garonne': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Potomac': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Moa': 网格(50,141), 深度=-274.2m, 海洋=True
#   可视化-河口 'Thu-Bon': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Panuco ': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Sassandra': 网格(41,177), 深度=-4446.9m, 海洋=True
#   可视化-河口 'Subarnarekha': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Chaliyar': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Nemanus': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Narmada': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Anadyr': 网格(70,91), 深度=-116.4m, 海洋=True
#   可视化-河口 'Tagus': 网格(59,174), 深度=-4133.5m, 海洋=True
#   可视化-河口 'Kalu Ganga': 网格(43,40), 深度=-1.9m, 海洋=True
#   可视化-河口 'Grande': 网格(52,132), 深度=-3028.4m, 海洋=True
#   可视化-河口 'Clyde': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Moyangjiang': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Grande de San Miguel': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Passaic': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Artibonite': 网格(51,144), 深度=-5165.2m, 海洋=True
#   可视化-河口 'Brenta': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Jiaojiang': 网格(54,62), 深度=-88.4m, 海洋=True
#   可视化-河口 'Kvichak': 网格(67,103), 深度=-4326.4m, 海洋=True
#   可视化-河口 'Wouri': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Sinú': 网格(46,141), 深度=-3857.0m, 海洋=True
#   可视化-河口 'Choshui': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Seyhan': 网格(48,27), 深度=-1369.4m, 海洋=True
#   可视化-河口 'Parnaiba': 网格(40,159), 深度=-4129.1m, 海洋=True
#   可视化-河口 'Naranjo': 网格(46,132), 深度=-4098.0m, 海洋=True
#   可视化-河口 'Pattani': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Kobuk': 网格(69,97), 深度=-28.5m, 海洋=True
#   可视化-河口 'Cuanza': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Escondido': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Cai': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Rajang': 网格(43,55), 深度=-1478.9m, 海洋=True
#   可视化-河口 'Ceyhan': 网格(48,28), 深度=-2802.1m, 海洋=True
#   可视化-河口 'Krishna': 网格(47,42), 深度=-3032.0m, 海洋=True
#   可视化-河口 'Lachish': 网格(47,26), 深度=-2027.8m, 海洋=True
#   可视化-河口 'Indigirka': 网格(69,74), 深度=-45.6m, 海洋=True
#   可视化-河口 'Los Angeles': 网格(55,119), 深度=-3881.0m, 海洋=True
#   可视化-河口 'Scheldt': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Coatzacoalcos': 网格(51,133), 深度=-3530.2m, 海洋=True
#   可视化-河口 'Loiza': 网格(49,147), 深度=-3612.4m, 海洋=True
#   可视化-河口 'Taan': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Tecolutla': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Mahaweli Ganga': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Bandama': 网格(41,177), 深度=-4446.9m, 海洋=True
#   可视化-河口 'Daugava': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Snohomish': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Cape Fear': 网格(56,142), 深度=-3769.6m, 海洋=True
#   可视化-河口 'Patuca': 网格(49,138), 深度=-3516.4m, 海洋=True
#   可视化-河口 'Nandujiang': 网格(49,57), 深度=-2442.9m, 海洋=True
#   可视化-河口 'Guanhe': 网格(55,62), 深度=-55.2m, 海洋=True
#   可视化-河口 'Severn': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Savannah': 网格(55,141), 深度=-1994.1m, 海洋=True
#   可视化-河口 'Keum': 网格(55,63), 深度=-110.7m, 海洋=True
#   可视化-河口 'Pamlico': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Mamberamo': 网格(40,69), 深度=-3961.7m, 海洋=True
#   可视化-河口 'Tevere': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Padas': 网格(44,58), 深度=-1130.0m, 海洋=True
#   可视化-河口 'Selangor': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Grande de Terraba': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Severnaya Dvina': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Koca?ay': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Ribble': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Tagum': 网格(45,63), 深度=-5992.1m, 海洋=True
#   可视化-河口 'St. John': 网格(49,149), 深度=-5627.4m, 海洋=True
#   可视化-河口 'Anseoung': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Kouilou': 网格(36,4), 深度=-4020.8m, 海洋=True
#   可视化-河口 'Tano': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Muvatupuzha': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Mogami': 网格(59,72), 深度=-5745.5m, 海洋=True
#   可视化-河口 'Büyük Menderes': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Asi': 网格(48,28), 深度=-2802.1m, 海洋=True
#   可视化-河口 'Fly': 网格(38,74), 深度=-1898.5m, 海洋=True
#   可视化-河口 'Rufiji': 网格(36,21), 深度=-3800.6m, 海洋=True
#   可视化-河口 'Trengganu': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Sekampung': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Neretva': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Oueme': 网格(41,1), 深度=-4097.9m, 海洋=True
#   可视化-河口 'Kinabatangan': 网格(43,60), 深度=-2516.2m, 海洋=True
#   可视化-河口 'Tapti': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Ba': 网格(31,74), 深度=-710.0m, 海洋=True
#   可视化-河口 'Santa Ana': 网格(55,119), 深度=-3881.0m, 海洋=True
#   可视化-河口 'Tugela': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Housatonic': 网格(59,145), 深度=-3093.4m, 海洋=True
#   可视化-河口 'Tolten': 网格(20,141), 深度=-4051.1m, 海洋=True
#   可视化-河口 'Opak': 网格(34,55), 深度=-4795.3m, 海洋=True
#   可视化-河口 'Chikugo': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Peedee': 网格(56,142), 深度=-3769.6m, 海洋=True
#   可视化-河口 'Buayan': 网格(43,64), 深度=-5533.2m, 海洋=True
#   可视化-河口 'Taymyra': 网格(60,65), 深度=-2916.2m, 海洋=True
#   可视化-河口 'Periyar ': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Dagua': 网格(42,139), 深度=-2558.5m, 海洋=True
#   可视化-河口 'Serang': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Nervion': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Manavgat': 网格(47,27), 深度=-2679.4m, 海洋=True
#   可视化-河口 'Noatak': 网格(70,95), 深度=-38.9m, 海洋=True
#   可视化-河口 'Achenkovil': 网格(45,41), 深度=-3551.1m, 海洋=True
#   可视化-河口 'Minho': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Sampit': 网格(36,58), 深度=-564.2m, 海洋=True
#   可视化-河口 'Kikori': 网格(38,74), 深度=-1898.5m, 海洋=True
#   可视化-河口 'Umgeni': 网格(25,17), 深度=-2202.0m, 海洋=True
#   可视化-河口 'Ogooue': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Kitakami': 网格(59,72), 深度=-5745.5m, 海洋=True
#   可视化-河口 'Jequitinhonha': 网格(32,161), 深度=-3988.1m, 海洋=True
#   可视化-河口 'Dnepr': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Douro': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Kizil Irmark': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Ebro': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Tulangbawang': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Sakarya': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Adour': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Adige': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Kamchatka': 网格(65,80), 深度=-5661.9m, 海洋=True
#   可视化-河口 'Paraiba': 网格(36,163), 深度=-4435.1m, 海洋=True
#   可视化-河口 'Tenryu': 网格(56,70), 深度=-3219.9m, 海洋=True
#   可视化-河口 'Yana': 网格(68,72), 深度=-236.0m, 海洋=True
#   可视化-河口 'Olenyok': 网格(68,70), 深度=-143.3m, 海洋=True
#   可视化-河口 'Pawan': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Agano': 网格(60,68), 深度=-3199.6m, 海洋=True
#   可视化-河口 'Siak': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Murar': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Roanoke': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Dordogne': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Pearl': 网格(53,135), 深度=-2377.9m, 海洋=True
#   可视化-河口 'Shebelle': 网格(40,24), 深度=-4684.6m, 海洋=True
#   可视化-河口 'Lanyang': 网格(52,62), 深度=-1234.9m, 海洋=True
#   可视化-河口 'Kallada': 网格(42,38), 深度=-2860.6m, 海洋=True
#   可视化-河口 'Caloosahatchee': 网格(53,140), 深度=-464.6m, 海洋=True
#   可视化-河口 'Maule': 网格(22,142), 深度=-4208.8m, 海洋=True
#   可视化-河口 'Micay': 网格(42,139), 深度=-2558.5m, 海洋=True
#   可视化-河口 'Pascua': 网格(13,141), 深度=-3983.1m, 海洋=True
#   可视化-河口 'Choluteca': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Seraju': 网格(34,55), 深度=-4795.3m, 海洋=True
#   可视化-河口 'St. John': 网格(49,149), 深度=-5627.4m, 海洋=True
#   可视化-河口 'Abukuma': 网格(59,72), 深度=-5745.5m, 海洋=True
#   可视化-河口 'James': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Abra': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'La Plata': 网格(20,152), 深度=-965.6m, 海洋=True
#   可视化-河口 'Catatumbo': 网格(47,144), 深度=-3872.7m, 海洋=True
#   可视化-河口 'Mono': 网格(41,1), 深度=-4097.9m, 海洋=True
#   可视化-河口 'Suchiate': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'El Harrach': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Cenrana': 网格(36,60), 深度=-2379.5m, 海洋=True
#   可视化-河口 'Nam San': 网格(49,55), 深度=-242.3m, 海洋=True
#   可视化-河口 'Panay': 网格(46,61), 深度=-275.3m, 海洋=True
#   可视化-河口 'Shkumbini': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'évros': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Aksu': 网格(52,31), 深度=-1012.6m, 海洋=True
#   可视化-河口 'Pamba ': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Pra': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Landek': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Jamapa': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Yeongsan': 网格(55,63), 深度=-110.7m, 海洋=True
#   可视化-河口 'Patuxent': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Naya': 网格(42,139), 深度=-2558.5m, 海洋=True
#   可视化-河口 'Axiós': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Asahan': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Tana': 网格(38,21), 深度=-3461.3m, 海洋=True
#   可视化-河口 'Kadalundi': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Chirripo del Atlanti': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Tyne': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Yaque del Sur': 网格(51,144), 深度=-5165.2m, 海洋=True
#   可视化-河口 'Penzhina': 网格(68,83), 深度=-3808.3m, 海洋=True
#   可视化-河口 'Uda': 网格(60,66), 深度=-3266.5m, 海洋=True
#   可视化-河口 'Leon': 网格(44,135), 深度=-3406.1m, 海洋=True
#   可视化-河口 'Muda': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Aconcagua': 网格(24,142), 深度=-4286.6m, 海洋=True
#   可视化-河口 'Mahi': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Boubo': 网格(41,177), 深度=-4446.9m, 海洋=True
#   可视化-河口 'Papagayo': 网格(44,135), 深度=-3406.1m, 海洋=True
#   可视化-河口 'Cess': 网格(41,175), 深度=-4483.1m, 海洋=True
#   可视化-河口 'Bakir': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Kü?ük Menderes': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Chalakudi': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Itapicuru': 网格(33,162), 深度=-4404.5m, 海洋=True
#   可视化-河口 'Russian': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Mankyong': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Antigua': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Mazaroni': 网格(45,151), 深度=-3876.6m, 海洋=True
#   可视化-河口 'Valapattanam': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Blanco': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Tagoloan': 网格(45,62), 深度=-281.5m, 海洋=True
#   可视化-河口 'Yaracuy': 网格(46,147), 深度=-3789.1m, 海洋=True
#   可视化-河口 'Rapel': 网格(23,142), 深度=-4190.6m, 海洋=True
#   可视化-河口 'Kaladan': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Santa Maria': 网格(52,132), 深度=-3028.4m, 海洋=True
#   可视化-河口 'Chiloango': 网格(36,4), 深度=-4020.8m, 海洋=True
#   可视化-河口 'Mearim': 网格(40,158), 深度=-4021.5m, 海洋=True
#   可视化-河口 'Chiriqui': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Rokan': 网格(38,48), 深度=-4711.8m, 海洋=True
#   可视化-河口 'Tempisque': 网格(44,135), 深度=-3406.1m, 海洋=True
#   可视化-河口 'Maha Oya': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Ouse': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Jintsu': 网格(57,71), 深度=-5922.8m, 海洋=True
#   可视化-河口 'Yoshino': 网格(55,67), 深度=-4361.5m, 海洋=True
#   可视化-河口 'Gediz': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Ysil Irmak': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Wadi Baraka': 网格(42,1), 深度=-3188.7m, 海洋=True
#   可视化-河口 'Mondego': 网格(60,174), 深度=-4000.6m, 海洋=True
#   可视化-河口 'Nautla ': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Seli': 网格(68,2), 深度=-71.8m, 海洋=True
#   可视化-河口 'Pregolua': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Tuhaihe': 网格(55,62), 深度=-55.2m, 海洋=True
#   可视化-河口 'Semani': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Pachang': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Sine': 网格(47,170), 深度=-3344.9m, 海洋=True
#   可视化-河口 'Narcea': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Sabine': 网格(53,133), 深度=-1360.2m, 海洋=True
#   可视化-河口 'Sadang': 网格(36,60), 深度=-2379.5m, 海洋=True
#   可视化-河口 'Una': 网格(32,161), 深度=-3988.1m, 海洋=True
#   可视化-河口 'Jubones': 网格(38,138), 深度=-2998.1m, 海洋=True
#   可视化-河口 'Polochic': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Baudo': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Cauto': 网格(50,142), 深度=-1299.4m, 海洋=True
#   可视化-河口 'Manati': 网格(49,147), 深度=-3612.4m, 海洋=True
#   可视化-河口 'Houlung': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Capiberibe': 网格(36,163), 深度=-4435.1m, 海洋=True
#   可视化-河口 'Cuvo': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Touchien': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Ikopa': 网格(31,26), 深度=-4718.4m, 海洋=True
#   可视化-河口 'Liffey': 网格(69,175), 深度=-1120.3m, 海洋=True
#   可视化-河口 'Tonala ': 网格(51,133), 深度=-3530.2m, 海洋=True
#   可视化-河口 'G?ksu': 网格(48,27), 深度=-1369.4m, 海洋=True
#   可视化-河口 'Netravati ': 网格(46,35), 深度=-2533.4m, 海洋=True
#   可视化-河口 'Rogue': 网格(61,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Kebir': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Changhuajiang': 网格(60,66), 深度=-3266.5m, 海洋=True
#   可视化-河口 'Pechora': 网格(72,19), 深度=-0.6m, 海洋=True
#   可视化-河口 'Motatan': 网格(47,144), 深度=-3872.7m, 海洋=True
#   可视化-河口 'Peikang': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Bueno': 网格(22,142), 深度=-4208.8m, 海洋=True
#   可视化-河口 'San Juan': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Anabar': 网格(68,70), 深度=-143.3m, 海洋=True
#   可视化-河口 'Puelo': 网格(19,141), 深度=-3801.7m, 海洋=True
#   可视化-河口 'Minho': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Waikato': 网格(22,88), 深度=-2273.2m, 海洋=True
#   可视化-河口 'Umzimkulu': 网格(25,17), 深度=-2202.0m, 海洋=True
#   可视化-河口 'Dalinghe': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Guadalupe': 网格(53,133), 深度=-1360.2m, 海洋=True
#   可视化-河口 'Markham': 网格(38,74), 深度=-1898.5m, 海洋=True
#   可视化-河口 'Esk': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Negro': 网格(20,152), 深度=-965.6m, 海洋=True
#   可视化-河口 'Rimac': 网格(33,139), 深度=-4707.8m, 海洋=True
#   可视化-河口 'Pindaré': 网格(40,158), 深度=-4021.5m, 海洋=True
#   可视化-河口 'Prinza Polka': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Mat': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Alas': 网格(42,46), 深度=-2987.5m, 海洋=True
#   可视化-河口 'Cazones': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Mand': 网格(51,31), 深度=-2850.0m, 海洋=True
#   可视化-河口 'Pasig': 网格(46,60), 深度=-348.8m, 海洋=True
#   可视化-河口 'Neches': 网格(53,133), 深度=-1360.2m, 海洋=True
#   可视化-河口 'Ooi': 网格(43,53), 深度=-52.8m, 海洋=True
#   可视化-河口 'Valdivia': 网格(20,141), 深度=-4051.1m, 海洋=True
#   可视化-河口 'Filyos': 网格(49,28), 深度=-63.5m, 海洋=True
#   可视化-河口 'Achigate': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Burhabalang': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Ikpikpuk': 网格(69,96), 深度=-36.7m, 海洋=True
#   可视化-河口 'Dee': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Nooksak': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Guanipa': 网格(46,148), 深度=-2183.2m, 海洋=True
#   可视化-河口 'Rioni': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Mungo': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Dayanghe': 网格(60,65), 深度=-2916.2m, 海洋=True
#   可视化-河口 'Sixaola': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Baram': 网格(44,57), 深度=-1848.7m, 海洋=True
#   可视化-河口 'Pojuca': 网格(33,162), 深度=-4404.5m, 海洋=True
#   可视化-河口 'Pascogoula': 网格(53,136), 深度=-2996.2m, 海洋=True
#   可视化-河口 'Bashee': 网格(51,62), 深度=-5004.5m, 海洋=True
#   可视化-河口 'Volturno': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Yenshui': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Cayapas': 网格(40,138), 深度=-3162.9m, 海洋=True
#   可视化-河口 'Kuzuryo': 网格(57,71), 深度=-5922.8m, 海洋=True
#   可视化-河口 'Pyasina': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Murung': 网格(43,55), 深度=-1478.9m, 海洋=True
#   可视化-河口 'Mzymta': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Llobregat': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Litani': 网格(48,27), 深度=-1369.4m, 海洋=True
#   可视化-河口 'Aguan': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Chowan': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Abulug': 网格(49,62), 深度=-5416.6m, 海洋=True
#   可视化-河口 'Arno': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Guadiana': 网格(58,174), 深度=-4030.1m, 海洋=True
#   可视化-河口 'Selawik': 网格(69,96), 深度=-36.7m, 海洋=True
#   可视化-河口 'Semegal': 网格(48,170), 深度=-3263.1m, 海洋=True
#   可视化-河口 'Sagavanirktok': 网格(69,106), 深度=-1810.5m, 海洋=True
#   可视化-河口 'Strimonas': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Iwaki': 网格(57,71), 深度=-5922.8m, 海洋=True
#   可视化-河口 'Vijose': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Milk': 网格(56,119), 深度=-3090.6m, 海洋=True
#   可视化-河口 'Paz': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Itapecuru': 网格(40,158), 深度=-4021.5m, 海洋=True
#   可视化-河口 'Bengo': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Choctawhatchee': 网格(53,136), 深度=-2996.2m, 海洋=True
#   可视化-河口 'Taura': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Suwannee': 网格(54,140), 深度=-781.8m, 海洋=True
#   可视化-河口 'Kennebeck': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Corubal': 网格(46,170), 深度=-4118.1m, 海洋=True
#   可视化-河口 'Chehalis': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Don Diego': 网格(47,143), 深度=-3387.2m, 海洋=True
#   可视化-河口 'Dniester': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Itata': 网格(22,142), 深度=-4208.8m, 海洋=True
#   可视化-河口 'Tocuyo': 网格(47,145), 深度=-4302.3m, 海洋=True
#   可视化-河口 'Sewa': 网格(42,173), 深度=-4454.5m, 海洋=True
#   可视化-河口 'Gangavati': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'Deduru Oya': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Bhadar': 网格(49,33), 深度=-3184.9m, 海洋=True
#   可视化-河口 'Suriname': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Fraser': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Agus': 网格(45,62), 深度=-281.5m, 海洋=True
#   可视化-河口 'Palar': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'Oum Er Rbia': 网格(57,174), 深度=-4303.8m, 海洋=True
#   可视化-河口 'Diep': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Itapemirim': 网格(29,161), 深度=-3221.4m, 海洋=True
#   可视化-河口 'Brazos': 网格(53,133), 深度=-1360.2m, 海洋=True
#   可视化-河口 'Munim': 网格(40,158), 深度=-4021.5m, 海洋=True
#   可视化-河口 'Skagit': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Estero Real': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Acaraú': 网格(39,161), 深度=-4111.9m, 海洋=True
#   可视化-河口 'Changuinola': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Kokem?njoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Narva': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Tra-Khuc': 网格(48,56), 深度=-1778.0m, 海洋=True
#   可视化-河口 'Panai': 网格(40,47), 深度=-4460.9m, 海洋=True
#   可视化-河口 'Umzimvubu': 网格(23,16), 深度=-3255.6m, 海洋=True
#   可视化-河口 'Tungkang': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Tsiribihina': 网格(30,20), 深度=-2498.4m, 海洋=True
#   可视化-河口 'Usk': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Chishui': 网格(50,57), 深度=-187.2m, 海洋=True
#   可视化-河口 'Paragua?u': 网格(33,162), 深度=-4404.5m, 海洋=True
#   可视化-河口 'Loukos': 网格(57,174), 深度=-4303.8m, 海洋=True
#   可视化-河口 'Vilaine': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Gurupi': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'Nanliuliang': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Lee': 网格(69,175), 深度=-1120.3m, 海洋=True
#   可视化-河口 'Cobre': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Hualien': 网格(52,62), 深度=-1234.9m, 海洋=True
#   可视化-河口 'Kalinadi': 网格(50,44), 深度=-241.7m, 海洋=True
#   可视化-河口 'Tauyo': 网格(63,73), 深度=-3243.2m, 海洋=True
#   可视化-河口 'Vasa Barris': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Kuzitrin': 网格(70,95), 深度=-38.9m, 海洋=True
#   可视化-河口 'Nagavali': 网格(48,43), 深度=-2587.9m, 海洋=True
#   可视化-河口 'Little Scarcies': 网格(43,171), 深度=-4794.9m, 海洋=True
#   可视化-河口 'Glomma': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Great Tenasserim': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Sharavati': 网格(46,35), 深度=-2533.4m, 海洋=True
#   可视化-河口 'Coyolate': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Dee': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Kamchatka': 网格(65,80), 深度=-5661.9m, 海洋=True
#   可视化-河口 'Hsiukuluan': 网格(51,62), 深度=-5004.5m, 海洋=True
#   可视化-河口 'Besos': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Sabarmati': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Tuxpan ': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Sambas': 网格(42,54), 深度=-98.7m, 海洋=True
#   可视化-河口 'Sa? Mateus': 网格(31,161), 深度=-2892.6m, 海洋=True
#   可视化-河口 'San Joaquin': 网格(57,117), 深度=-4440.3m, 海洋=True
#   可视化-河口 'Johore': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Yarra': 网格(19,71), 深度=-3021.0m, 海洋=True
#   可视化-河口 'Moju': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'Liaohe': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Piranhas': 网格(35,163), 深度=-4633.3m, 海洋=True
#   可视化-河口 'Linpien': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Hellah': 网格(49,29), 深度=-2849.0m, 海洋=True
#   可视化-河口 'Cebollati': 网格(23,155), 深度=-2471.0m, 海洋=True
#   可视化-河口 'Da Nhim': 网格(46,56), 深度=-3791.2m, 海洋=True
#   可视化-河口 'Nyong': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Cheongchun': 网格(55,63), 深度=-110.7m, 海洋=True
#   可视化-河口 'Rappahannock': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Erhjen': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Cunene': 网格(31,4), 深度=-4504.7m, 海洋=True
#   可视化-河口 'Lobe': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'Acheloos': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Save': 网格(29,19), 深度=-2782.9m, 海洋=True
#   可视化-河口 'Piave': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Kuparuk': 网格(69,105), 深度=-289.3m, 海洋=True
#   可视化-河口 'Incomati': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Ca?ar': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Samala': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Peace': 网格(64,115), 深度=-2404.7m, 海洋=True
#   可视化-河口 'Guanajibo': 网格(49,146), 深度=-3788.8m, 海洋=True
#   可视化-河口 'Wye': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Seumjin': 网格(55,63), 深度=-110.7m, 海洋=True
#   可视化-河口 'Mendawai': 网格(36,58), 深度=-564.2m, 海洋=True
#   可视化-河口 'Shannon': 网格(66,173), 深度=-400.1m, 海洋=True
#   可视化-河口 'San Pablo': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Portoviejo': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Penobscot': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Nelson': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Ponnaiyar': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'Sampara': 网格(38,62), 深度=-4544.7m, 海洋=True
#   可视化-河口 'Iyidere': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Amguema': 网格(70,87), 深度=-1595.0m, 海洋=True
#   可视化-河口 'Wadi Ghoweibba': 网格(46,25), 深度=-1932.2m, 海洋=True
#   可视化-河口 'Exe': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Potzu': 网格(50,60), 深度=-2146.3m, 海洋=True
#   可视化-河口 'Limpopo': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Konkoure': 网格(43,171), 深度=-4794.9m, 海洋=True
#   可视化-河口 'Khroma': 网格(69,74), 深度=-45.6m, 海洋=True
#   可视化-河口 'Saint John's': 网格(49,149), 深度=-5627.4m, 海洋=True
#   可视化-河口 'St. John': 网格(49,149), 深度=-5627.4m, 海洋=True
#   可视化-河口 'Tees': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Walawe Ganga': 网格(43,40), 深度=-1.9m, 海洋=True
#   可视化-河口 'Escambia': 网格(53,136), 深度=-2996.2m, 海洋=True
#   可视化-河口 'Actopán': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Zohreh': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Lielupe': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Kul': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Majiahe': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Guadalquivir': 网格(58,174), 深度=-4030.1m, 海洋=True
#   可视化-河口 'Pardo': 网格(26,157), 深度=-2326.4m, 海洋=True
#   可视化-河口 'Utukok': 网格(71,95), 深度=-24.5m, 海洋=True
#   可视化-河口 'Androscoggin': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Cuyuni': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'K?prü': 网格(48,28), 深度=-2802.1m, 海洋=True
#   可视化-河口 'Vamsadhara': 网格(48,43), 深度=-2587.9m, 海洋=True
#   可视化-河口 'Melet': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Peinan': 网格(51,62), 深度=-5004.5m, 海洋=True
#   可视化-河口 'Wadi Nugaal': 网格(45,26), 深度=-2738.5m, 海洋=True
#   可视化-河口 'Sebou': 网格(57,174), 深度=-4303.8m, 海洋=True
#   可视化-河口 'Lurio': 网格(34,21), 深度=-2780.6m, 海洋=True
#   可视化-河口 'Pulau': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Mesuji': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Kelik': 网格(42,54), 深度=-98.7m, 海洋=True
#   可视化-河口 'Umfolozi': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Mangoro': 网格(31,26), 深度=-4718.4m, 海洋=True
#   可视化-河口 'Tamesi': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Endau': 网格(42,53), 深度=-78.8m, 海洋=True
#   可视化-河口 'Rushikulya': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Chone': 网格(40,138), 深度=-3162.9m, 海洋=True
#   可视化-河口 'Petch': 网格(46,47), 深度=-1667.8m, 海洋=True
#   可视化-河口 'Avon': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Kola': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Tokachi': 网格(61,73), 深度=-3442.6m, 海洋=True
#   可视化-河口 'Demerara': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Mucuri': 网格(31,161), 深度=-2892.6m, 海洋=True
#   可视化-河口 'Luala': 网格(36,61), 深度=-2712.6m, 海洋=True
#   可视化-河口 'Guapi': 网格(42,139), 深度=-2558.5m, 海洋=True
#   可视化-河口 'Lofa': 网格(42,173), 深度=-4454.5m, 海洋=True
#   可视化-河口 'Orange': 网格(25,6), 深度=-3114.9m, 海洋=True
#   可视化-河口 'Umhlantuzi': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Liri': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Barranca': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Penner': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'Hii': 网格(59,66), 深度=-2253.4m, 海洋=True
#   可视化-河口 'Unare': 网格(46,147), 深度=-3789.1m, 海洋=True
#   可视化-河口 'Velikaya': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Sebaou': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Pinios': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Mharhar': 网格(48,34), 深度=-3506.5m, 海洋=True
#   可视化-河口 'Kymijoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Kavik': 网格(69,106), 深度=-1810.5m, 海洋=True
#   可视化-河口 'Omoloy': 网格(69,74), 深度=-45.6m, 海洋=True
#   可视化-河口 'Galana': 网格(38,21), 深度=-3461.3m, 海洋=True
#   可视化-河口 'Ameca': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Casamance': 网格(46,170), 深度=-4118.1m, 海洋=True
#   可视化-河口 'Soumman': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Deba': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Kukpuk': 网格(71,95), 深度=-24.5m, 海洋=True
#   可视化-河口 'Kokulik': 网格(71,95), 深度=-24.5m, 海洋=True
#   可视化-河口 'Nene': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Berbice': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Venta': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Yenisei': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Turia?o': 网格(40,158), 深度=-4021.5m, 海洋=True
#   可视化-河口 'Barrow': 网格(70,96), 深度=-6.1m, 海洋=True
#   可视化-河口 'Sesjab': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Jaba': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Coporolo': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Groot Berg': 网格(28,5), 深度=-3496.4m, 海洋=True
#   可视化-河口 'Canning': 网格(69,107), 深度=-2826.8m, 海洋=True
#   可视化-河口 'Edisto': 网格(55,141), 深度=-1994.1m, 海洋=True
#   可视化-河口 'Gambia': 网格(47,170), 深度=-3344.9m, 海洋=True
#   可视化-河口 'Tugur': 网格(67,71), 深度=-272.7m, 海洋=True
#   可视化-河口 'Breede': 网格(21,10), 深度=-2364.0m, 海洋=True
#   可视化-河口 'Mbemkuru': 网格(35,21), 深度=-3591.4m, 海洋=True
#   可视化-河口 'Hutt': 网格(26,55), 深度=-3835.7m, 海洋=True
#   可视化-河口 'Suir': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Essequibo': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Apodi': 网格(38,162), 深度=-3484.0m, 海洋=True
#   可视化-河口 'Ogeechee': 网格(55,141), 深度=-1994.1m, 海洋=True
#   可视化-河口 'Longa': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Omotepec': 网格(46,131), 深度=-3855.7m, 海洋=True
#   可视化-河口 'Koyuk': 网格(69,96), 深度=-36.7m, 海洋=True
#   可视化-河口 'Jong': 网格(42,173), 深度=-4454.5m, 海洋=True
#   可视化-河口 'Goumo': 网格(42,2), 深度=-575.5m, 海洋=True
#   可视化-河口 'Oria': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Umkomazi': 网格(25,17), 深度=-2202.0m, 海洋=True
#   可视化-河口 'Tabasara': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Santa': 网格(33,139), 深度=-4707.8m, 海洋=True
#   可视化-河口 'Corantijin': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'Umvoti': 网格(25,17), 深度=-2202.0m, 海洋=True
#   可视化-河口 'Bayano': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Kadalundi': 网格(44,36), 深度=-2161.3m, 海洋=True
#   可视化-河口 'Wadi Zabid': 网格(46,25), 深度=-1932.2m, 海洋=True
#   可视化-河口 'Presido': 网格(52,125), 深度=-978.3m, 海洋=True
#   可视化-河口 'Yura': 网格(59,72), 深度=-5745.5m, 海洋=True
#   可视化-河口 'Bradano': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Kuloy': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Ter': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Saco': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Reno': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Kalamas': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Fish Creek': 网格(69,96), 深度=-36.7m, 海洋=True
#   可视化-河口 'Maputo': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Mahuri': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Lena': 网格(68,72), 深度=-236.0m, 海洋=True
#   可视化-河口 'Shou': 网格(50,59), 深度=-2668.4m, 海洋=True
#   可视化-河口 'Umpqua': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Charente': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Swakop': 网格(28,5), 深度=-3496.4m, 海洋=True
#   可视化-河口 'Colorado': 网格(53,121), 深度=-3738.6m, 海洋=True
#   可视化-河口 'M'Bridge': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Toa': 网格(50,142), 深度=-1299.4m, 海洋=True
#   可视化-河口 'Hoping': 网格(52,62), 深度=-1234.9m, 海洋=True
# ...
#   可视化-河口 'Camaquá': 网格(23,155), 深度=-2471.0m, 海洋=True
#   可视化-河口 'Ntem': 网格(40,3), 深度=-2732.2m, 海洋=True
#   可视化-河口 'San Diego Creek': 网格(55,119), 深度=-3881.0m, 海洋=True
#   可视化-河口 'Rauchua': 网格(69,87), 深度=-3664.3m, 海洋=True
#   可视化-河口 'Don': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Vellar': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'Apuko': 网格(49,44), 深度=-1854.3m, 海洋=True
#   可视化-河口 'Mangoky': 网格(29,20), 深度=-2941.8m, 海洋=True
#   可视化-河口 'Tuloma': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Bou Regreg': 网格(57,174), 深度=-4303.8m, 海洋=True
#   可视化-河口 'Crati': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Wadi Bana': 网格(46,26), 深度=-1745.8m, 海洋=True
#   可视化-河口 'Lune': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Nyanga': 网格(39,3), 深度=-2952.5m, 海洋=True
#   可视化-河口 'Ulbeya': 网格(60,68), 深度=-3199.6m, 海洋=True
#   可视化-河口 'Aliakmon': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Kocabas': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Eel': 网格(60,116), 深度=-3140.5m, 海洋=True
#   可视化-河口 'Teith': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Wami': 网格(37,21), 深度=-3827.0m, 海洋=True
#   可视化-河口 'Klamath': 网格(61,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Waimakariri': 网格(16,86), 深度=-1501.4m, 海洋=True
#   可视化-河口 'Huixtla': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Saguenay': 网格(61,148), 深度=-888.3m, 海洋=True
#   可视化-河口 'Wadi al Hamd': 网格(46,26), 深度=-1745.8m, 海洋=True
#   可视化-河口 'Jaguaribe': 网格(39,161), 深度=-4111.9m, 海洋=True
#   可视化-河口 'Sapgyo': 网格(55,63), 深度=-110.7m, 海洋=True
#   可视化-河口 'Nekor': 网格(58,175), 深度=-1572.8m, 海洋=True
#   可视化-河口 'Gallikos': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Herault': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Barumun': 网格(38,48), 深度=-4711.8m, 海洋=True
#   可视化-河口 'Blackwater': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Cacheu': 网格(46,170), 深度=-4118.1m, 海洋=True
#   可视化-河口 'Churo': 网格(36,58), 深度=-564.2m, 海洋=True
#   可视化-河口 'Tagliamento': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Gundlakamma': 网格(46,41), 深度=-3383.3m, 海洋=True
#   可视化-河口 'York': 网格(57,143), 深度=-4076.4m, 海洋=True
#   可视化-河口 'Polyavaam': 网格(68,74), 深度=-194.5m, 海洋=True
#   可视化-河口 'Culiacan': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Manawatu': 网格(20,90), 深度=-3514.6m, 海洋=True
#   可视化-河口 'Kogon': 网格(52,31), 深度=-1012.6m, 海洋=True
#   可视化-河口 'Santa Lucia': 网格(57,174), 深度=-4303.8m, 海洋=True
#   可视化-河口 'Xiaolinghe': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Matandu': 网格(35,21), 深度=-3591.4m, 海洋=True
#   可视化-河口 'Teshio': 网格(63,73), 深度=-3243.2m, 海洋=True
#   可视化-河口 'Madre Vieja': 网格(46,132), 深度=-4098.0m, 海洋=True
#   可视化-河口 'Kalar': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Seybousse': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Segura': 网格(62,176), 深度=-4451.9m, 海洋=True
#   可视化-河口 'Towry': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Drammenselva': 网格(68,2), 深度=-71.8m, 海洋=True
#   可视化-河口 'Buzi': 网格(29,19), 深度=-2782.9m, 海洋=True
#   可视化-河口 'Tamraparni': 网格(43,40), 深度=-1.9m, 海洋=True
#   可视化-河口 'Argens': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Pakhacha': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Ketanda': 网格(34,6), 深度=-1069.0m, 海洋=True
#   可视化-河口 'Yarcon': 网格(47,27), 深度=-2679.4m, 海洋=True
#   可视化-河口 'Moy': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Monapo': 网格(33,21), 深度=-3129.4m, 海洋=True
#   可视化-河口 'Eden': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Ashburton': 网格(31,59), 深度=-1175.1m, 海洋=True
#   可视化-河口 'Takhoyams': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Punta Gorda': 网格(47,139), 深度=-695.0m, 海洋=True
#   可视化-河口 'Welland': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'M'Lela': 网格(39,22), 深度=-3853.7m, 海洋=True
#   可视化-河口 'Angerman': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Tweed': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Savio': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Marowijne': 网格(44,153), 深度=-3680.2m, 海洋=True
#   可视化-河口 'Mana': 网格(43,155), 深度=-4044.4m, 海洋=True
#   可视化-河口 'Hawkesbury': 网格(23,77), 深度=-4611.8m, 海洋=True
#   可视化-河口 'Harsit': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Ankobra': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Simeto': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Rancheria': 网格(47,144), 深度=-3872.7m, 海洋=True
#   可视化-河口 'Aude': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Esino': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Pyr': 网格(47,128), 深度=-3300.5m, 海洋=True
#   可视化-河口 'Armeria': 网格(40,60), 深度=-997.5m, 海洋=True
#   可视化-河口 'Kahajan': 网格(46,26), 深度=-1745.8m, 海洋=True
#   可视化-河口 'Wadi Tuban': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Dande': 网格(39,24), 深度=-4873.2m, 海洋=True
#   可视化-河口 'Dharror': 网格(66,113), 深度=-1720.9m, 海洋=True
#   可视化-河口 'Lenivaya': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Sele': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Skiensvassdraget': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Mokihinui': 网格(21,85), 深度=-1860.7m, 海洋=True
#   可视化-河口 'Elota': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Tay': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Tambo': 网格(30,142), 深度=-4641.5m, 海洋=True
#   可视化-河口 'Maduru Oya': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Matigulu': 网格(25,17), 深度=-2202.0m, 海洋=True
#   可视化-河口 'Chillon': 网格(33,139), 深度=-4707.8m, 海洋=True
#   可视化-河口 'Volta': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Turia': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Slupa': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Arenillas': 网格(38,138), 深度=-2998.1m, 海洋=True
#   可视化-河口 'Merauke': 网格(34,69), 深度=-54.7m, 海洋=True
#   可视化-河口 'Tuira': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Skafta': 网格(70,171), 深度=-2447.9m, 海洋=True
#   可视化-河口 'G?ta alv': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Catumbela': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Guantanamo': 网格(50,142), 深度=-1299.4m, 海洋=True
#   可视化-河口 'Pescara': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Silup': 网格(67,73), 深度=-841.4m, 海洋=True
#   可视化-河口 'Ioniveyem': 网格(70,90), 深度=-369.2m, 海洋=True
#   可视化-河口 'Oulujoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Onega': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Smith': 网格(21,9), 深度=-3720.9m, 海洋=True
#   可视化-河口 'Parsenta': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Clutha': 网格(17,82), 深度=-4446.2m, 海洋=True
#   可视化-河口 'Seputih': 网格(35,52), 深度=-5352.6m, 海洋=True
#   可视化-河口 'Slaney': 网格(64,176), 深度=-140.1m, 海洋=True
#   可视化-河口 'Yukon': 网格(69,109), 深度=-1488.6m, 海洋=True
#   可视化-河口 'Serujan': 网格(42,54), 深度=-98.7m, 海洋=True
#   可视化-河口 'Umba': 网格(37,21), 深度=-3827.0m, 海洋=True
#   可视化-河口 'Arachtos': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Agrioun': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'El Fuerte': 网格(51,124), 深度=-1899.6m, 海洋=True
#   可视化-河口 'Jucar': 网格(62,176), 深度=-4451.9m, 海洋=True
#   可视化-河口 'Los Esclavos': 网格(45,134), 深度=-3739.7m, 海洋=True
#   可视化-河口 'Salso': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Negro': 网格(21,154), 深度=-4268.7m, 海洋=True
#   可视化-河口 'Balao': 网格(39,138), 深度=-1831.8m, 海洋=True
#   可视化-河口 'Ngaruroro': 网格(20,90), 深度=-3514.6m, 海洋=True
#   可视化-河口 'Wadi Masilah': 网格(46,26), 深度=-1745.8m, 海洋=True
#   可视化-河口 'Siletz': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'George': 网格(21,11), 深度=-3897.3m, 海洋=True
#   可视化-河口 'Lariang': 网格(40,60), 深度=-997.5m, 海洋=True
#   可视化-河口 'Bemarivo': 网格(33,26), 深度=-4549.6m, 海洋=True
#   可视化-河口 'Patahparang': 网格(35,24), 深度=-4464.0m, 海洋=True
#   可视化-河口 'Bristane': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'Gal Oya': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Hab': 网格(51,31), 深度=-2850.0m, 海洋=True
#   可视化-河口 'Mourne': 网格(69,175), 深度=-1120.3m, 海洋=True
#   可视化-河口 'Orb': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Mayo': 网格(43,172), 深度=-4358.5m, 海洋=True
#   可视化-河口 'Chancay': 网格(33,139), 深度=-4707.8m, 海洋=True
#   可视化-河口 'Saramacca': 网格(44,152), 深度=-2908.5m, 海洋=True
#   可视化-河口 'P?rnu': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Matanuska': 网格(68,105), 深度=-3586.3m, 海洋=True
#   可视化-河口 'Isser': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Balombo': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Mehran': 网格(51,30), 深度=-3169.5m, 海洋=True
#   可视化-河口 'Whanganui': 网格(22,87), 深度=-864.3m, 海洋=True
#   可视化-河口 'Krka': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Sinaloa': 网格(51,124), 深度=-1899.6m, 海洋=True
#   可视化-河口 'Ruamahanga': 网格(18,88), 深度=-1018.2m, 海洋=True
#   可视化-河口 'Larona': 网格(40,60), 深度=-997.5m, 海洋=True
#   可视化-河口 'Araguari': 网格(41,156), 深度=-2048.4m, 海洋=True
#   可视化-河口 'San Lorenzo': 网格(45,140), 深度=-3128.3m, 海洋=True
#   可视化-河口 'Mad': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Skjalfandafljot': 网格(70,171), 深度=-2447.9m, 海洋=True
#   可视化-河口 'Alfios': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Kurobe': 网格(57,71), 深度=-5922.8m, 海洋=True
#   可视化-河口 'Tillamook': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Mahavavy Nord': 网格(33,22), 深度=-2992.9m, 海洋=True
#   可视化-河口 'Agri': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Jiquini?a': 网格(39,159), 深度=-3409.5m, 海洋=True
#   可视化-河口 'Yuzhny Bug': 网格(51,29), 深度=-616.0m, 海洋=True
#   可视化-河口 'Basento': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Wadi Siham': 网格(46,25), 深度=-1932.2m, 海洋=True
#   可视化-河口 'Sperchios': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Umbeluzi': 网格(26,17), 深度=-1447.6m, 海洋=True
#   可视化-河口 'Kukalaya, Huahua': 网格(47,139), 深度=-695.0m, 海洋=True
#   可视化-河口 'Rovuma': 网格(34,21), 深度=-2780.6m, 海洋=True
#   可视化-河口 'Digul': 网格(35,68), 深度=-50.1m, 海洋=True
#   可视化-河口 'Licungo': 网格(29,19), 深度=-2782.9m, 海洋=True
#   可视化-河口 'Jagin': 网格(51,30), 深度=-3169.5m, 海洋=True
#   可视化-河口 'Ayensu': 网格(41,178), 深度=-4574.7m, 海洋=True
#   可视化-河口 'Maticora': 网格(38,66), 深度=-125.3m, 海洋=True
#   可视化-河口 'Baleine': 网格(62,150), 深度=-146.0m, 海洋=True
#   可视化-河口 'Arnaud': 网格(71,148), 深度=-231.8m, 海洋=True
#   可视化-河口 'Soto la Marina': 网格(52,132), 深度=-3028.4m, 海洋=True
#   可视化-河口 'Ness': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Kamchea': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Curoca': 网格(31,4), 深度=-4504.7m, 海洋=True
#   可视化-河口 'Tirso': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Sella': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Hokitika': 网格(20,84), 深度=-540.0m, 海洋=True
#   可视化-河口 'Kala Oya': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Marequelia': 网格(47,142), 深度=-3886.1m, 海洋=True
#   可视化-河口 'Khobi': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Aux Feuilles': 网格(71,148), 深度=-231.8m, 海洋=True
#   可视化-河口 'Rapch': 网格(71,149), 深度=-615.4m, 海洋=True
#   可视化-河口 'Misantia': 网格(46,25), 深度=-1932.2m, 海洋=True
#   可视化-河口 'Annan': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Jequetepeque': 网格(36,138), 深度=-4164.0m, 海洋=True
#   可视化-河口 'Musone': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Alazeya': 网格(69,74), 深度=-45.6m, 海洋=True
#   可视化-河口 'Guadalhorce': 网格(58,175), 深度=-1572.8m, 海洋=True
#   可视化-河口 'Tet': 网格(67,1), 深度=-36.2m, 海洋=True
#   可视化-河口 'Fatala': 网格(43,171), 深度=-4794.9m, 海洋=True
#   可视化-河口 'Acaponeta': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Conway': 网格(21,85), 深度=-1860.7m, 海洋=True
#   可视化-河口 'Piura': 网格(37,138), 深度=-3810.5m, 海洋=True
#   可视化-河口 'Tarsus': 网格(48,27), 深度=-1369.4m, 海洋=True
#   可视化-河口 'Kurinwas': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Baluarte': 网格(50,125), 深度=-2909.9m, 海洋=True
#   可视化-河口 'Biferno': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Chico': 网格(58,143), 深度=-2981.9m, 海洋=True
#   可视化-河口 'Kidurong': 网格(44,57), 深度=-1848.7m, 海洋=True
#   可视化-河口 'Nehalem': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Tutong': 网格(44,57), 深度=-1848.7m, 海洋=True
#   可视化-河口 'Cambongo': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Knik': 网格(68,105), 深度=-3586.3m, 海洋=True
#   可视化-河口 'Yaqui': 网格(51,124), 深度=-1899.6m, 海洋=True
#   可视化-河口 'Petit Mecatina': 网格(68,151), 深度=-2330.2m, 海洋=True
#   可视化-河口 'Navia': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Cihuatlan': 网格(48,126), 深度=-3504.1m, 海洋=True
#   可视化-河口 'Inguri': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Sarstoon': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Austari-Vestari': 网格(70,169), 深度=-2268.3m, 海洋=True
#   可视化-河口 'Tehuantepec': 网格(46,132), 深度=-4098.0m, 海洋=True
#   可视化-河口 'Dhuudo': 网格(45,26), 深度=-2738.5m, 海洋=True
#   可视化-河口 'Aruvi Aru': 网格(44,41), 深度=-3731.6m, 海洋=True
#   可视化-河口 'Kemijoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Champoton': 网格(50,137), 深度=-3484.3m, 海洋=True
#   可视化-河口 'Ombrone': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Boko': 网格(36,4), 深度=-4020.8m, 海洋=True
#   可视化-河口 'Coquille': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Rega': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Back': 网格(60,146), 深度=-845.4m, 海洋=True
#   可视化-河口 'Alsea': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Chienti': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Salado': 网格(58,148), 深度=-4954.4m, 海洋=True
#   可视化-河口 'Wadi Araba': 网格(47,26), 深度=-2027.8m, 海洋=True
#   可视化-河口 'Vaidala': 网格(35,30), 深度=-1593.2m, 海洋=True
#   可视化-河口 'Cubal': 网格(34,5), 深度=-3456.1m, 海洋=True
#   可视化-河口 'Numedalslagen': 网格(68,1), 深度=-73.8m, 海洋=True
#   可视化-河口 'Kaituna': 网格(21,10), 深度=-2364.0m, 海洋=True
#   可视化-河口 'Lamone': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Siuslaw': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Candelaria': 网格(18,135), 深度=-3797.6m, 海洋=True
#   可视化-河口 'Mulatos': 网格(49,142), 深度=-2268.9m, 海洋=True
#   可视化-河口 'Black': 网格(54,141), 深度=-2184.3m, 海洋=True
#   可视化-河口 'Santa Clara': 网格(56,118), 深度=-4171.6m, 海洋=True
#   可视化-河口 'Sondags': 网格(21,12), 深度=-4055.5m, 海洋=True
#   可视化-河口 'Supsa': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Moche': 网格(37,138), 深度=-3810.5m, 海洋=True
#   可视化-河口 'Kyronjoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'San Juan': 网格(46,139), 深度=-1602.1m, 海洋=True
#   可视化-河口 'Belize': 网格(49,137), 深度=-3997.0m, 海洋=True
#   可视化-河口 'Tafna': 网格(57,175), 深度=-3496.7m, 海洋=True
#   可视化-河口 'Deveron': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Mano': 网格(42,173), 深度=-4454.5m, 海洋=True
#   可视化-河口 'Wailuku': 网格(50,102), 深度=-4319.4m, 海洋=True
#   可视化-河口 'Hondo': 网格(52,132), 深度=-3028.4m, 海洋=True
#   可视化-河口 'Fortore': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Kem': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Segama': 网格(42,60), 深度=-3133.5m, 海洋=True
#   可视化-河口 'Conon': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Ancho': 网格(51,132), 深度=-3322.2m, 海洋=True
#   可视化-河口 'Grey': 网格(16,86), 深度=-1501.4m, 海洋=True
#   可视化-河口 'Aisen': 网格(17,141), 深度=-3079.0m, 海洋=True
#   可视化-河口 'Foglia': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Mananara Sud': 网格(32,26), 深度=-4563.3m, 海洋=True
#   可视化-河口 'Coos': 网格(62,116), 深度=-2868.1m, 海洋=True
#   可视化-河口 'Sangro': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Malaren-Norrstrom': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Marecchia': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Tenna': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Sembakung': 网格(42,60), 深度=-3133.5m, 海洋=True
#   可视化-河口 'Ofanto': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Mackenzie': 网格(68,110), 深度=-3203.1m, 海洋=True
#   可视化-河口 'Souss': 网格(55,173), 深度=-2554.3m, 海洋=True
#   可视化-河口 'Lupar': 网格(43,55), 深度=-1478.9m, 海洋=True
#   可视化-河口 'Earn': 网格(70,178), 深度=-735.9m, 海洋=True
#   可视化-河口 'Tarawera': 网格(22,88), 深度=-2273.2m, 海洋=True
#   可视化-河口 'Staaten': 网格(33,73), 深度=-3148.4m, 海洋=True
#   可视化-河口 'Lapuanjoki': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'San Diego': 网格(55,119), 深度=-3881.0m, 海洋=True
#   可视化-河口 'Curimataú': 网格(37,163), 深度=-4328.2m, 海洋=True
#   可视化-河口 'Tronto': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Louros': 网格(67,3), 深度=-30.9m, 海洋=True
#   可视化-河口 'Laxa': 网格(70,169), 深度=-2268.3m, 海洋=True
#   可视化-河口 'Misa': 网格(67,2), 深度=-39.7m, 海洋=True
#   可视化-河口 'Sinni': 网格(59,145), 深度=-3093.4m, 海洋=True
#   可视化-河口 'Povungnituk': 网格(58,61), 深度=-39.7m, 海洋=True
#   可视化-河口 'Bian': 网格(49,28), 深度=-63.5m, 海洋=True
#   可视化-河口 'Ligonha': 网格(33,4), 深度=-4452.8m, 海洋=True
#   可视化-河口 'Mananan Tanana': 网格(68,3), 深度=-109.5m, 海洋=True
#   可视化-河口 'Huab': 网格(52,30), 深度=-970.6m, 海洋=True
#   可视化-河口 'Devrekani': 网格(63,176), 深度=-3289.5m, 海洋=True
#   可视化-河口 'Tamar': 网格(55,119), 深度=-3881.0m, 海洋=True
# /tmp/ipykernel_248/1527206378.py:312: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap1 = plt.cm.get_cmap('viridis').copy()
# /tmp/ipykernel_248/1527206378.py:323: UserWarning: Glyph 179 (\N{SUPERSCRIPT THREE}) missing from font(s) SimHei.
#   plt.tight_layout()
# /tmp/ipykernel_248/1527206378.py:324: UserWarning: Glyph 179 (\N{SUPERSCRIPT THREE}) missing from font(s) SimHei.
#   plt.savefig(f'{output_dir}/global_concentration.png', dpi=300, bbox_inches='tight')
# /root/miniconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 179 (\N{SUPERSCRIPT THREE}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)
# 6. 写入MITgcm输入文件...
# 写入二进制文件: input/microplastic_initial.bin
# 文件大小: 2.20 MB
# 写入二进制文件: input/microplastic_rbcs_target.bin
# 文件大小: 2.20 MB
# 写入二进制文件: input/microplastic_rbcs_mask.bin
# 文件大小: 2.20 MB
#
# ============================================================
# 微塑料模拟完成!
# ============================================================
#
# 模拟完成! 生成的3D场形状: (40, 80, 180)
# 文件已保存到: input/microplastic_initial.bin
